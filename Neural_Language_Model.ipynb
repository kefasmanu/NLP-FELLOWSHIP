# %% [markdown]
# <a href="https://colab.research.google.com/github/kefasmanu/NLP-FELLOWSHIP/blob/main/Neural_Language_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Word Embeddings
# Word embeddings were proposed by  [Bengio et. al. (2001, 2003)](https://www.jmlr.org/papers/volume3/bengio03a/bengio03a.pdf)
#
# From the dataset, the neural network would identify the words with similar meaning, but also preserve the words semantic (properties of word boy - young, male, human) and syntatic (word order, noun, grammatic relationship) propoerties.
#
# The cat is walking in the bedroom
#
# A dog was running in a room
#
# The cat is running in a room
#
# A dog is walking in a bedroom
#
# The dog was walking in the room
#
# This neural network has three components:
#
# 1. An embedding layer that generates word embedding, and the parameters are shared across words.
#   * It’s a lookup table, given the index, it will return the corresponding vector.
#   * The vector representation indicated the weighted matrix is initialized as random values and will be updated by backpropagation
# 2. A hidden layer of one or more layers, which introduces non-linearity to the embeddings.
# 3. A softmax function that produces probability distribution over all the words in the vocabulary.
#
# The words would be represented in a dense vector
# * dog [0.2,0.5,-1.5,2.4] (length of vector is set as a parameter)

# %% [markdown]
# ## Step 1: Get the dataset

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
import pandas as pd
path = '/content/gdrive/MyDrive/NLP FELLOWSHIP/data/IMDB Dataset.csv' # Enter your path
#os.chdir(path)
# !ls
# Out:
# gdrive	sample_data

# %%
dataset = pd.read_csv(path)
dataset.head(100)
# Out:
#                                                review sentiment
# 0   One of the other reviewers has mentioned that ...  positive
# 1   A wonderful little production. <br /><br />The...  positive
# 2   I thought this was a wonderful way to spend ti...  positive
# 3   Basically there's a family where a little boy ...  negative
# 4   Petter Mattei's "Love in the Time of Money" is...  positive
# ..                                                ...       ...
# 95  Daniel Day-Lewis is the most versatile actor a...  positive
# 96  My guess would be this was originally going to...  negative
# 97  Well, I like to watch bad horror B-Movies, cau...  negative
# 98  This IS the worst movie I have ever seen, as w...  negative
# 99  I have been a Mario fan for as long as I can r...  positive
#
# [100 rows x 2 columns]

# %%
dataset.describe()
# Out:
#                                                    review sentiment
# count                                               50000     50000
# unique                                              49582         2
# top     Loved today's show!!! It was a variety and not...  positive
# freq                                                    5     25000

# %%
english_text = list(set(dataset['review'])) #Depends on your data. Change code
english_text = english_text[:5000]
print(len(english_text))
# Out:
# 5000

# %%
import re
def preprocess(text):
    text = text.lower()
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               "]+", flags=re.UNICODE)
    
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    html_pattern = re.compile('<.*?>')
    text = emoji_pattern.sub(r'', text)
    text = url_pattern.sub(r'', text)
    text = html_pattern.sub(r'', text)
    text = re.sub(r"[^\w\d'\s]+", ' ', text)

    return text

# %%
processed_english_text = []
for sent in english_text:
  processed_english_text.append(preprocess(sent))

print(len(processed_english_text))
processed_english_text[:5]
# Out:
# 5000
# ["a wonderful story about the consequences of obsessive love with the beautiful romantic back streets of paris as its location  we're transported through time and see the plot develop from the perspectives of the three main characters as the mystery unwinds ",
#  "ok  imagine that every state in the us  nay  every country has exactly the same trees growing and ground foliage  imagine  also  that a monkey trapper's camp so far off the beaten track you had to do the first half of the approach by river has a beautifully tarmac'd  perfectly straight road leading up to it  imagine a world where you have to wear a full biohazard suit to collect a floppy disk  then you just drop it in a ziploc bag and transfer it to your pocket with no precautions as soon as you get back to the office  a world where two nine year old girls are happy to give lots of blood without complaining  this is the world this movie is set in on top of that  it's one of the most cliché ridden pieces of excrement it's been my misfortune to witness in many a year i liked it   ",
#  "so good  the acting  cutting  directing in there may not be the best ever  but the dancing  the moves  the heat and the passion in this movie is definitely the best  well atleast for me   it really touched me  inspired me to learn dancing  i even especially registered to this site just so i could vote on it and contribute my support for this movie  for this movie  it literally gave me goosebumps when i watched it  i love it  jennifer grey is so pretty  patrick is so sexy in there  the first thing i'll do tomorrow  on my way to university will be to drop by the video store n buy a copy of it  n watch it again n again till i am old n wrinkly n cant dance with the movie any longer  before than i need to learn all the dance moves there ",
#  "forget depth of meaning  leave your logic at the door  and have a great time with this maniacally funny  totally absurdist  ultra campy live action  cartoon  mystery men is a send up of every superhero flick you've ever seen  but its unlikely super wannabes are so interesting  varied  and well cast that they are memorable characters in their own right  dark humor  downright silliness  bona fide action  and even a touching moment or two  combine to make this comic fantasy about lovable losers a true winner  the comedic talents of the actors playing the mystery men   including one mystery woman   are a perfect foil for wes studi as what can only be described as a bargain basement yoda  and geoffrey rush as one of the most off the wall  and bizarrely charming  villains ever to walk off the pages of a dark horse comic book and onto the big screen  get ready to laugh  cheer  and say  huh  more than once  enjoy ",
#  "my wife is a teacher and she is very familiar with the story  having read it to several of her classes  it never sounded all that interesting to me  though  and i bought the dvd figuring this would be a movie that wouldn't really be up my alley the first half of the movie has a lot of set up and i found myself thinking that i was right  it starts off a bit slow and i have to admit that i was a little bit bored   but curious enough to stay with it  boy  am i glad i did because this ended up being a very satisfying and rewarding movie  i would most certainly watch this again the casting was very good  since i haven't read the book  i can't vouch for accuracy  but i have to say that jon voight was truly delightful  you liked the characters you were supposed to like  hated the ones you were supposed to hate  and laughed at the ones that were supposed to be funny i can see how some folks might not like this movie  it is tedious at times  especially in the beginning  all the flashbacks can be distracting  though they are essential to the story  once the story starts to come together at the end  though  i think you're paid back in spades for your patience  when all is said and done  i think this is a very good movie   8 10 "]

# %% [markdown]
# ## Step 2: index the words

# %%
UNK_symbol = "<UNK>"
all_words = set([UNK_symbol])
word_to_index = {}
index_to_word = {}
for sentence in processed_english_text:
  words = [token for token in sentence.split() ]
  all_words.update(words)

for index,value in enumerate(all_words):
  word_to_index[value] = index
  index_to_word[index] = value
  
n_class = len(word_to_index) # number of Vocabulary

print(n_class)
# Out:
# 43341

# %%
sorted(word_to_index, key=word_to_index.get)[10:40]
# Out:
# ['gertrúdix',
#  'jayne',
#  'reunited',
#  'junge',
#  'considerations',
#  'maps',
#  'balaclavas',
#  'minutest',
#  'officials',
#  'lapping',
#  'simplified',
#  'berg',
#  'boneheads',
#  "girolamo'",
#  'rudeness',
#  'absenteeism',
#  'strumpets',
#  'sadism',
#  'arch',
#  'bladerunner',
#  'monotheism',
#  'burrowed',
#  'fancied',
#  'bran',
#  'loneliness',
#  'michaelsen',
#  'impersonation',
#  'macbeth',
#  'teenage',
#  'younger']

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader
import time

torch.cuda.empty_cache()
if torch.cuda.is_available():
  device = torch.device("cuda")
else:
  device = torch.device("cpu")

# %%
def create_input_target(list_sentences):
  input_batch = []
  target_batch = []

  for sen in list_sentences:
      word = sen.split() # space tokenizer
      input = [word_to_index[n] for n in word[:-1]] # create (1~n-1) as input (every word in the sentence except the last word)
      target = word_to_index[word[-1]] # create (n) as target, We usually call this 'casual language model'

      input_batch.append(torch.tensor(input))
      target_batch.append(target)

  return input_batch,target_batch

# %% [markdown]
# ## Build the model

# %%
#Use this cell for testing the shape of input when passed through different layers
X =nn.Embedding(n_class, 2)(input_batch)
X=X.view(-1, 2 * 2)
tanh = torch.tanh(nn.Parameter(torch.ones(2)) + nn.Linear(2 * 2, 2, bias=False)(X))
nn.Parameter(torch.ones(2))
nn.Linear(2 * 2, 2, bias=False)
nn.Linear(2, n_class, bias=False)
nn.Linear(2 * 2, n_class, bias=False)
nn.Parameter(torch.ones(n_class))
torch.LongTensor(input_batch[0])
tanh.shape
# Out:
# torch.Size([3182500, 2])

# %%
class NNLM(nn.Module):
    def __init__(self):
        super(NNLM, self).__init__()
        self.embeddings = nn.Embedding(n_class, m)
        self.hidden1 = nn.Linear(n_step * m, n_hidden, bias=False)
        self.ones = nn.Parameter(torch.ones(n_hidden))
        self.hidden2 = nn.Linear(n_hidden, n_class, bias=False)
        self.hidden3 = nn.Linear(n_step * m, n_class, bias=False)
        self.bias = nn.Parameter(torch.ones(n_class))

    def forward(self, X):
        X = self.embeddings(X) # X : [batch_size, n_step, m]
        
        #X = X.flatten()
        X = X.view(-1, n_step * m) # [batch_size, n_step * m] first layer (-1 flattens the tensor)
        
        tanh = torch.tanh(self.ones + self.hidden1(X)) # [batch_size, n_hidden] pass embedded layer through first hidden layet and add bias. The result is passed through tanh function
        
        output = self.bias + self.hidden3(X) + self.hidden2(tanh) # [batch_size, n_class]
        return output

if __name__ == '__main__':
  n_step = 2 # number of steps, n-1 in paper
  n_hidden = 2 # number of hidden size, h in paper
  m = 10 # embedding size, m in paper,( batch size)
  
  gpu = 0
  input_batch,target_batch = create_input_target(processed_english_text)
  input_batch = torch.LongTensor(pad_sequence(input_batch))
  train_loader = DataLoader(input_batch, batch_size = 10, num_workers = 1)
  
  target_batch = torch.LongTensor(target_batch)
  dev_loader = DataLoader(target_batch, batch_size = 10, num_workers = 1)
  

  model = NNLM()
  model.cuda(gpu)

  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
for epoch in range(50):
    st = time.time()
    
    for it, data_tensor in enumerate(train_loader):  
      
      context_tensor = data_tensor[:,0:2]
      target_tensor = data_tensor[:,2]

      context_tensor, target_tensor = context_tensor.cuda(gpu), target_tensor.cuda(gpu)

      optimizer.zero_grad()
      output = model(context_tensor)

      #acc = get_accuracy_from_log_probs(output, target_tensor)

      # output : [batch_size, n_class], target_batch : [batch_size]
      loss = criterion(output, target_tensor)
      if (epoch + 1) % 5 == 0:
          print('Epoch:', '%04d' % (epoch + 1), 'cost =', '{:.6f}'.format(loss),'output size: ',output.size)

      loss.backward()
      optimizer.step()

      if it % 500 == 0: 
        print("Training Iteration {} of epoch {} complete. Loss: {}; Time taken (s): {}".format(it, epoch, loss.item(), (time.time()-st)))
        st = time.time()

      
      # set best model path
      best_model_path = '/content/model/best_model_{}.dat'.format(epoch)
      # saving best model
      torch.save(model.state_dict(), best_model_path)
# Out:
# Training Iteration 0 of epoch 0 complete. Loss: 0.38401034474372864; Time taken (s): 0.040978431701660156
# Training Iteration 0 of epoch 1 complete. Loss: 0.293291836977005; Time taken (s): 0.03849959373474121
# Training Iteration 0 of epoch 2 complete. Loss: 0.27753785252571106; Time taken (s): 0.038176774978637695
# Training Iteration 0 of epoch 3 complete. Loss: 0.2618409991264343; Time taken (s): 0.03797626495361328
# Epoch: 0005 cost = 0.246580 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Training Iteration 0 of epoch 4 complete. Loss: 0.24657995998859406; Time taken (s): 0.04490947723388672
# Epoch: 0005 cost = 0.259639 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0005 cost = 0.508099 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.402277 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 1.823355 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 1.698142 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 1.734839 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0005 cost = 1.410969 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 1.413140 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 1.763669 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0005 cost = 1.394085 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 1.731772 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0005 cost = 1.421746 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0005 cost = 1.544136 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 1.498468 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0005 cost = 0.557155 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0005 cost = 0.001040 output size:  <built-in method size of Tensor object at 0x7fccbc32d7d0>
# Epoch: 0005 cost = 0.001034 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0005 cost = 0.001029 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.001023 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 0.001018 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.001014 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0005 cost = 0.001009 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 0.001005 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0005 cost = 0.001002 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.000998 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 0.000995 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0005 cost = 0.000992 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 0.000989 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0005 cost = 0.000986 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0005 cost = 0.000983 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0005 cost = 0.000980 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0005 cost = 0.000978 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.000975 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0005 cost = 0.000973 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.000970 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 0.000968 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0005 cost = 0.000966 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0005 cost = 0.000964 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0005 cost = 0.000961 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.000959 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0005 cost = 0.000958 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0005 cost = 0.000955 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0005 cost = 0.000954 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0005 cost = 0.000951 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0005 cost = 0.000950 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0005 cost = 0.000948 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.000946 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.000944 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0005 cost = 0.000942 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.000941 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0005 cost = 0.000939 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.000937 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.000936 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0005 cost = 0.000934 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0005 cost = 0.000932 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0005 cost = 0.000930 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0005 cost = 0.000929 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0005 cost = 0.000927 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0005 cost = 0.000925 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0005 cost = 0.000924 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0005 cost = 0.000922 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 0.000921 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0005 cost = 0.000919 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.000917 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0005 cost = 0.000916 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.000914 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0005 cost = 0.000912 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0005 cost = 0.000911 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0005 cost = 0.000909 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.000908 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.000906 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0005 cost = 0.000905 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.000903 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0005 cost = 0.000902 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0005 cost = 0.000900 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0005 cost = 0.000898 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.000897 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0005 cost = 0.000895 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0005 cost = 0.000894 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.000892 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0005 cost = 0.000891 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0005 cost = 0.000889 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.000888 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0005 cost = 0.000886 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 0.000885 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0005 cost = 0.000883 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0005 cost = 0.000882 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0005 cost = 0.000881 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0005 cost = 0.000879 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.000878 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 0.000876 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0005 cost = 0.000875 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0005 cost = 0.000873 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 0.000872 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.000870 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0005 cost = 0.000869 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0005 cost = 0.000867 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.000866 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.000864 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0005 cost = 0.000863 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0005 cost = 0.000862 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0005 cost = 0.000860 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0005 cost = 0.000859 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.000857 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0005 cost = 0.000856 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.000855 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0005 cost = 0.000853 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0005 cost = 0.000852 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0005 cost = 0.000850 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0005 cost = 0.000849 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 0.000848 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0005 cost = 0.000846 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.000845 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 0.000843 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0005 cost = 0.000842 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0005 cost = 0.000841 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.000839 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 0.000838 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0005 cost = 0.000837 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0005 cost = 0.000835 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.000834 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 0.000833 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.000831 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0005 cost = 0.000830 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0005 cost = 0.000829 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0005 cost = 0.000827 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0005 cost = 0.000826 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Training Iteration 0 of epoch 5 complete. Loss: 0.23192067444324493; Time taken (s): 0.04592585563659668
# Training Iteration 0 of epoch 6 complete. Loss: 0.21795491874217987; Time taken (s): 0.039350032806396484
# Training Iteration 0 of epoch 7 complete. Loss: 0.20472967624664307; Time taken (s): 0.05009174346923828
# Training Iteration 0 of epoch 8 complete. Loss: 0.19226130843162537; Time taken (s): 0.039588212966918945
# Epoch: 0010 cost = 0.180546 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Training Iteration 0 of epoch 9 complete. Loss: 0.18054552376270294; Time taken (s): 0.045163869857788086
# Epoch: 0010 cost = 0.176926 output size:  <built-in method size of Tensor object at 0x7fccbc32dbf0>
# Epoch: 0010 cost = 0.372252 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0010 cost = 0.312289 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0010 cost = 1.688742 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0010 cost = 1.535247 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0010 cost = 1.569131 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0010 cost = 1.285326 output size:  <built-in method size of Tensor object at 0x7fccbc32dbf0>
# Epoch: 0010 cost = 1.248304 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0010 cost = 1.596582 output size:  <built-in method size of Tensor object at 0x7fccbc32d3b0>
# Epoch: 0010 cost = 1.227381 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0010 cost = 1.579201 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0010 cost = 1.280065 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0010 cost = 1.387990 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0010 cost = 1.355913 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0010 cost = 0.503785 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0010 cost = 0.000799 output size:  <built-in method size of Tensor object at 0x7fccbc32d7d0>
# Epoch: 0010 cost = 0.000793 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0010 cost = 0.000787 output size:  <built-in method size of Tensor object at 0x7fccbc32dbf0>
# Epoch: 0010 cost = 0.000782 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0010 cost = 0.000778 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0010 cost = 0.000773 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0010 cost = 0.000769 output size:  <built-in method size of Tensor object at 0x7fccbc32d7d0>
# Epoch: 0010 cost = 0.000766 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0010 cost = 0.000762 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0010 cost = 0.000759 output size:  <built-in method size of Tensor object at 0x7fccbc32d7d0>
# Epoch: 0010 cost = 0.000756 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0010 cost = 0.000753 output size:  <built-in method size of Tensor object at 0x7fccbc32dbf0>
# Epoch: 0010 cost = 0.000751 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0010 cost = 0.000748 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0010 cost = 0.000746 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0010 cost = 0.000744 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0010 cost = 0.000742 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0010 cost = 0.000740 output size:  <built-in method size of Tensor object at 0x7fccbc32d3b0>
# Epoch: 0010 cost = 0.000738 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0010 cost = 0.000736 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0010 cost = 0.000735 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0010 cost = 0.000733 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0010 cost = 0.000731 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0010 cost = 0.000730 output size:  <built-in method size of Tensor object at 0x7fccbc32d3b0>
# Epoch: 0010 cost = 0.000728 output size:  <built-in method size of Tensor object at 0x7fccbc32d7d0>
# Epoch: 0010 cost = 0.000727 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0010 cost = 0.000725 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0010 cost = 0.000724 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0010 cost = 0.000722 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0010 cost = 0.000721 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0010 cost = 0.000720 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0010 cost = 0.000718 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0010 cost = 0.000717 output size:  <built-in method size of Tensor object at 0x7fccbc32d7d0>
# Epoch: 0010 cost = 0.000716 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0010 cost = 0.000715 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0010 cost = 0.000714 output size:  <built-in method size of Tensor object at 0x7fccbc32dbf0>
# Epoch: 0010 cost = 0.000712 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0010 cost = 0.000711 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0010 cost = 0.000710 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0010 cost = 0.000709 output size:  <built-in method size of Tensor object at 0x7fccbc32d7d0>
# Epoch: 0010 cost = 0.000708 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0010 cost = 0.000707 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0010 cost = 0.000706 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0010 cost = 0.000704 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0010 cost = 0.000703 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0010 cost = 0.000702 output size:  <built-in method size of Tensor object at 0x7fccbc32d050>
# Epoch: 0010 cost = 0.000701 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0010 cost = 0.000700 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0010 cost = 0.000699 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0010 cost = 0.000698 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0010 cost = 0.000697 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0010 cost = 0.000696 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0010 cost = 0.000694 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0010 cost = 0.000694 output size:  <built-in method size of Tensor object at 0x7fccbc32d7d0>
# Epoch: 0010 cost = 0.000692 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0010 cost = 0.000691 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0010 cost = 0.000690 output size:  <built-in method size of Tensor object at 0x7fccbc32d7d0>
# Epoch: 0010 cost = 0.000689 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0010 cost = 0.000688 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0010 cost = 0.000687 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0010 cost = 0.000686 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0010 cost = 0.000685 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0010 cost = 0.000684 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0010 cost = 0.000683 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0010 cost = 0.000682 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0010 cost = 0.000681 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0010 cost = 0.000680 output size:  <built-in method size of Tensor object at 0x7fccbc32dbf0>
# Epoch: 0010 cost = 0.000679 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0010 cost = 0.000678 output size:  <built-in method size of Tensor object at 0x7fccbc32d7d0>
# Epoch: 0010 cost = 0.000677 output size:  <built-in method size of Tensor object at 0x7fccbc32d050>
# Epoch: 0010 cost = 0.000676 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0010 cost = 0.000675 output size:  <built-in method size of Tensor object at 0x7fccbc32d7d0>
# Epoch: 0010 cost = 0.000674 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0010 cost = 0.000673 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0010 cost = 0.000672 output size:  <built-in method size of Tensor object at 0x7fccbc32d050>
# Epoch: 0010 cost = 0.000671 output size:  <built-in method size of Tensor object at 0x7fccbc32d3b0>
# Epoch: 0010 cost = 0.000670 output size:  <built-in method size of Tensor object at 0x7fccbc32dbf0>
# Epoch: 0010 cost = 0.000669 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0010 cost = 0.000668 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0010 cost = 0.000668 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0010 cost = 0.000666 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0010 cost = 0.000665 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0010 cost = 0.000665 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0010 cost = 0.000664 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0010 cost = 0.000662 output size:  <built-in method size of Tensor object at 0x7fccbc32dbf0>
# Epoch: 0010 cost = 0.000661 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0010 cost = 0.000661 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0010 cost = 0.000660 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0010 cost = 0.000659 output size:  <built-in method size of Tensor object at 0x7fccbc32d050>
# Epoch: 0010 cost = 0.000658 output size:  <built-in method size of Tensor object at 0x7fccbc32d7d0>
# Epoch: 0010 cost = 0.000657 output size:  <built-in method size of Tensor object at 0x7fccbc32d3b0>
# Epoch: 0010 cost = 0.000656 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0010 cost = 0.000655 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0010 cost = 0.000654 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0010 cost = 0.000653 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0010 cost = 0.000652 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0010 cost = 0.000651 output size:  <built-in method size of Tensor object at 0x7fccbc32d050>
# Epoch: 0010 cost = 0.000650 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0010 cost = 0.000649 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0010 cost = 0.000648 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0010 cost = 0.000647 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0010 cost = 0.000647 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0010 cost = 0.000646 output size:  <built-in method size of Tensor object at 0x7fccbc32d050>
# Epoch: 0010 cost = 0.000645 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0010 cost = 0.000644 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0010 cost = 0.000643 output size:  <built-in method size of Tensor object at 0x7fccbc32dbf0>
# Epoch: 0010 cost = 0.000642 output size:  <built-in method size of Tensor object at 0x7fccbc32d7d0>
# Epoch: 0010 cost = 0.000641 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0010 cost = 0.000640 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0010 cost = 0.000639 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0010 cost = 0.000638 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0010 cost = 0.000638 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Training Iteration 0 of epoch 10 complete. Loss: 0.16956526041030884; Time taken (s): 0.15377259254455566
# Training Iteration 0 of epoch 11 complete. Loss: 0.1592942327260971; Time taken (s): 0.04150533676147461
# Training Iteration 0 of epoch 12 complete. Loss: 0.14970064163208008; Time taken (s): 0.0408017635345459
# Training Iteration 0 of epoch 13 complete. Loss: 0.14074885845184326; Time taken (s): 0.038474321365356445
# Epoch: 0015 cost = 0.132401 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Training Iteration 0 of epoch 14 complete. Loss: 0.1324007362127304; Time taken (s): 0.047002553939819336
# Epoch: 0015 cost = 0.126414 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0015 cost = 0.277724 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0015 cost = 0.246985 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0015 cost = 1.562428 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0015 cost = 1.397835 output size:  <built-in method size of Tensor object at 0x7fccbc32d230>
# Epoch: 0015 cost = 1.421484 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0015 cost = 1.180805 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0015 cost = 1.102553 output size:  <built-in method size of Tensor object at 0x7fccbc32d230>
# Epoch: 0015 cost = 1.444091 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0015 cost = 1.088362 output size:  <built-in method size of Tensor object at 0x7fccbc32d290>
# Epoch: 0015 cost = 1.445135 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0015 cost = 1.161339 output size:  <built-in method size of Tensor object at 0x7fccbc32d0b0>
# Epoch: 0015 cost = 1.255589 output size:  <built-in method size of Tensor object at 0x7fccbc32d170>
# Epoch: 0015 cost = 1.233793 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0015 cost = 0.448895 output size:  <built-in method size of Tensor object at 0x7fccbc32db90>
# Epoch: 0015 cost = 0.000634 output size:  <built-in method size of Tensor object at 0x7fccbc32d170>
# Epoch: 0015 cost = 0.000629 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0015 cost = 0.000624 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0015 cost = 0.000619 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0015 cost = 0.000615 output size:  <built-in method size of Tensor object at 0x7fccbc32d0b0>
# Epoch: 0015 cost = 0.000611 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0015 cost = 0.000607 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0015 cost = 0.000604 output size:  <built-in method size of Tensor object at 0x7fccbc32d290>
# Epoch: 0015 cost = 0.000601 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0015 cost = 0.000598 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0015 cost = 0.000595 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0015 cost = 0.000593 output size:  <built-in method size of Tensor object at 0x7fccbc32db90>
# Epoch: 0015 cost = 0.000591 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0015 cost = 0.000589 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0015 cost = 0.000587 output size:  <built-in method size of Tensor object at 0x7fccbc32db90>
# Epoch: 0015 cost = 0.000585 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0015 cost = 0.000583 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0015 cost = 0.000582 output size:  <built-in method size of Tensor object at 0x7fccbc32db90>
# Epoch: 0015 cost = 0.000580 output size:  <built-in method size of Tensor object at 0x7fccbc32d290>
# Epoch: 0015 cost = 0.000579 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0015 cost = 0.000577 output size:  <built-in method size of Tensor object at 0x7fccbc32dd10>
# Epoch: 0015 cost = 0.000576 output size:  <built-in method size of Tensor object at 0x7fccbc32d0b0>
# Epoch: 0015 cost = 0.000575 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0015 cost = 0.000573 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0015 cost = 0.000572 output size:  <built-in method size of Tensor object at 0x7fccbc32d0b0>
# Epoch: 0015 cost = 0.000571 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0015 cost = 0.000570 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0015 cost = 0.000569 output size:  <built-in method size of Tensor object at 0x7fccbc32dbf0>
# Epoch: 0015 cost = 0.000568 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0015 cost = 0.000567 output size:  <built-in method size of Tensor object at 0x7fccbc32db90>
# Epoch: 0015 cost = 0.000566 output size:  <built-in method size of Tensor object at 0x7fccbc32dbf0>
# Epoch: 0015 cost = 0.000565 output size:  <built-in method size of Tensor object at 0x7fccbc32d290>
# Epoch: 0015 cost = 0.000564 output size:  <built-in method size of Tensor object at 0x7fccbc32dad0>
# Epoch: 0015 cost = 0.000563 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0015 cost = 0.000562 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0015 cost = 0.000562 output size:  <built-in method size of Tensor object at 0x7fccbc32dd10>
# Epoch: 0015 cost = 0.000561 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0015 cost = 0.000560 output size:  <built-in method size of Tensor object at 0x7fccbc32dad0>
# Epoch: 0015 cost = 0.000559 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0015 cost = 0.000558 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0015 cost = 0.000557 output size:  <built-in method size of Tensor object at 0x7fccbc32dad0>
# Epoch: 0015 cost = 0.000557 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0015 cost = 0.000556 output size:  <built-in method size of Tensor object at 0x7fccbc32dbf0>
# Epoch: 0015 cost = 0.000555 output size:  <built-in method size of Tensor object at 0x7fccbc32d230>
# Epoch: 0015 cost = 0.000554 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0015 cost = 0.000553 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0015 cost = 0.000553 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0015 cost = 0.000552 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0015 cost = 0.000551 output size:  <built-in method size of Tensor object at 0x7fccbc32d0b0>
# Epoch: 0015 cost = 0.000550 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0015 cost = 0.000549 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0015 cost = 0.000549 output size:  <built-in method size of Tensor object at 0x7fccbc32dad0>
# Epoch: 0015 cost = 0.000548 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0015 cost = 0.000547 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0015 cost = 0.000546 output size:  <built-in method size of Tensor object at 0x7fccbc32d230>
# Epoch: 0015 cost = 0.000546 output size:  <built-in method size of Tensor object at 0x7fccbc32d290>
# Epoch: 0015 cost = 0.000545 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0015 cost = 0.000544 output size:  <built-in method size of Tensor object at 0x7fccbc32d230>
# Epoch: 0015 cost = 0.000544 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0015 cost = 0.000543 output size:  <built-in method size of Tensor object at 0x7fccbc32dbf0>
# Epoch: 0015 cost = 0.000542 output size:  <built-in method size of Tensor object at 0x7fccbc32dad0>
# Epoch: 0015 cost = 0.000542 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0015 cost = 0.000541 output size:  <built-in method size of Tensor object at 0x7fccbc32dbf0>
# Epoch: 0015 cost = 0.000540 output size:  <built-in method size of Tensor object at 0x7fccbc32dad0>
# Epoch: 0015 cost = 0.000539 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0015 cost = 0.000539 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0015 cost = 0.000538 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0015 cost = 0.000537 output size:  <built-in method size of Tensor object at 0x7fccbc32dd70>
# Epoch: 0015 cost = 0.000537 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0015 cost = 0.000536 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0015 cost = 0.000535 output size:  <built-in method size of Tensor object at 0x7fccbc32d170>
# Epoch: 0015 cost = 0.000534 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0015 cost = 0.000534 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0015 cost = 0.000533 output size:  <built-in method size of Tensor object at 0x7fccbc32d230>
# Epoch: 0015 cost = 0.000533 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0015 cost = 0.000532 output size:  <built-in method size of Tensor object at 0x7fccbc32d770>
# Epoch: 0015 cost = 0.000531 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0015 cost = 0.000530 output size:  <built-in method size of Tensor object at 0x7fccbc32dad0>
# Epoch: 0015 cost = 0.000530 output size:  <built-in method size of Tensor object at 0x7fccbc32d230>
# Epoch: 0015 cost = 0.000529 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0015 cost = 0.000529 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0015 cost = 0.000528 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0015 cost = 0.000527 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0015 cost = 0.000526 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0015 cost = 0.000526 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0015 cost = 0.000525 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0015 cost = 0.000524 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0015 cost = 0.000524 output size:  <built-in method size of Tensor object at 0x7fccbc32dd70>
# Epoch: 0015 cost = 0.000523 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0015 cost = 0.000522 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0015 cost = 0.000522 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0015 cost = 0.000521 output size:  <built-in method size of Tensor object at 0x7fccbc32d170>
# Epoch: 0015 cost = 0.000520 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0015 cost = 0.000519 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0015 cost = 0.000519 output size:  <built-in method size of Tensor object at 0x7fccbc32d170>
# Epoch: 0015 cost = 0.000518 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0015 cost = 0.000517 output size:  <built-in method size of Tensor object at 0x7fccbc32db90>
# Epoch: 0015 cost = 0.000517 output size:  <built-in method size of Tensor object at 0x7fccbc32d170>
# Epoch: 0015 cost = 0.000516 output size:  <built-in method size of Tensor object at 0x7fccbc32dd70>
# Epoch: 0015 cost = 0.000515 output size:  <built-in method size of Tensor object at 0x7fccbc32db30>
# Epoch: 0015 cost = 0.000515 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0015 cost = 0.000514 output size:  <built-in method size of Tensor object at 0x7fccbc32dd70>
# Epoch: 0015 cost = 0.000514 output size:  <built-in method size of Tensor object at 0x7fccbc32d0b0>
# Epoch: 0015 cost = 0.000513 output size:  <built-in method size of Tensor object at 0x7fccbc32d6b0>
# Epoch: 0015 cost = 0.000512 output size:  <built-in method size of Tensor object at 0x7fccbc32d230>
# Epoch: 0015 cost = 0.000512 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0015 cost = 0.000511 output size:  <built-in method size of Tensor object at 0x7fccbc32d290>
# Epoch: 0015 cost = 0.000510 output size:  <built-in method size of Tensor object at 0x7fccbc32db90>
# Epoch: 0015 cost = 0.000510 output size:  <built-in method size of Tensor object at 0x7fccbc32dd10>
# Epoch: 0015 cost = 0.000509 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0015 cost = 0.000509 output size:  <built-in method size of Tensor object at 0x7fccbc32db90>
# Epoch: 0015 cost = 0.000508 output size:  <built-in method size of Tensor object at 0x7fccbc32dd10>
# Training Iteration 0 of epoch 15 complete. Loss: 0.12461817264556885; Time taken (s): 0.043395042419433594
# Training Iteration 0 of epoch 16 complete. Loss: 0.11736370623111725; Time taken (s): 0.03844451904296875
# Training Iteration 0 of epoch 17 complete. Loss: 0.11060067266225815; Time taken (s): 0.03922724723815918
# Training Iteration 0 of epoch 18 complete. Loss: 0.10429352521896362; Time taken (s): 0.05373787879943848
# Epoch: 0020 cost = 0.098409 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Training Iteration 0 of epoch 19 complete. Loss: 0.09840913116931915; Time taken (s): 0.04773759841918945
# Epoch: 0020 cost = 0.093357 output size:  <built-in method size of Tensor object at 0x7fccbc32d410>
# Epoch: 0020 cost = 0.209185 output size:  <built-in method size of Tensor object at 0x7fccbc32d170>
# Epoch: 0020 cost = 0.198192 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0020 cost = 1.443363 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0020 cost = 1.281476 output size:  <built-in method size of Tensor object at 0x7fccbc32d170>
# Epoch: 0020 cost = 1.292173 output size:  <built-in method size of Tensor object at 0x7fccbc32d290>
# Epoch: 0020 cost = 1.094590 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0020 cost = 0.974751 output size:  <built-in method size of Tensor object at 0x7fccbc32d230>
# Epoch: 0020 cost = 1.308633 output size:  <built-in method size of Tensor object at 0x7fccbc32d290>
# Epoch: 0020 cost = 0.973469 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0020 cost = 1.326777 output size:  <built-in method size of Tensor object at 0x7fccbc32d230>
# Epoch: 0020 cost = 1.061501 output size:  <built-in method size of Tensor object at 0x7fccbc32d290>
# Epoch: 0020 cost = 1.142669 output size:  <built-in method size of Tensor object at 0x7fccbc32dcb0>
# Epoch: 0020 cost = 1.132677 output size:  <built-in method size of Tensor object at 0x7fccbc32d230>
# Epoch: 0020 cost = 0.393172 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0020 cost = 0.000518 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0020 cost = 0.000513 output size:  <built-in method size of Tensor object at 0x7fccbc32d0b0>
# Epoch: 0020 cost = 0.000508 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0020 cost = 0.000504 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0020 cost = 0.000500 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0020 cost = 0.000496 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0020 cost = 0.000493 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0020 cost = 0.000490 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0020 cost = 0.000488 output size:  <built-in method size of Tensor object at 0x7fccbc32d8f0>
# Epoch: 0020 cost = 0.000485 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0020 cost = 0.000483 output size:  <built-in method size of Tensor object at 0x7fccbc32dcb0>
# Epoch: 0020 cost = 0.000481 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0020 cost = 0.000479 output size:  <built-in method size of Tensor object at 0x7fccbc32db90>
# Epoch: 0020 cost = 0.000477 output size:  <built-in method size of Tensor object at 0x7fccbc32dcb0>
# Epoch: 0020 cost = 0.000475 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0020 cost = 0.000474 output size:  <built-in method size of Tensor object at 0x7fccbc32db90>
# Epoch: 0020 cost = 0.000472 output size:  <built-in method size of Tensor object at 0x7fccbc32dcb0>
# Epoch: 0020 cost = 0.000471 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0020 cost = 0.000470 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0020 cost = 0.000468 output size:  <built-in method size of Tensor object at 0x7fccbc32da70>
# Epoch: 0020 cost = 0.000467 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0020 cost = 0.000466 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0020 cost = 0.000465 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0020 cost = 0.000464 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0020 cost = 0.000463 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0020 cost = 0.000463 output size:  <built-in method size of Tensor object at 0x7fccbc32d290>
# Epoch: 0020 cost = 0.000462 output size:  <built-in method size of Tensor object at 0x7fccbc32db90>
# Epoch: 0020 cost = 0.000461 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0020 cost = 0.000460 output size:  <built-in method size of Tensor object at 0x7fccbc32dad0>
# Epoch: 0020 cost = 0.000459 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0020 cost = 0.000459 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0020 cost = 0.000458 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0020 cost = 0.000457 output size:  <built-in method size of Tensor object at 0x7fccbc32d0b0>
# Epoch: 0020 cost = 0.000456 output size:  <built-in method size of Tensor object at 0x7fccbc32d950>
# Epoch: 0020 cost = 0.000455 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0020 cost = 0.000455 output size:  <built-in method size of Tensor object at 0x7fccbc32d0b0>
# Epoch: 0020 cost = 0.000454 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0020 cost = 0.000454 output size:  <built-in method size of Tensor object at 0x7fccbc32d9b0>
# Epoch: 0020 cost = 0.000453 output size:  <built-in method size of Tensor object at 0x7fccbc32d0b0>
# Epoch: 0020 cost = 0.000452 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0020 cost = 0.000452 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0020 cost = 0.000451 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0020 cost = 0.000451 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0020 cost = 0.000450 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0020 cost = 0.000449 output size:  <built-in method size of Tensor object at 0x7fccbc32d710>
# Epoch: 0020 cost = 0.000449 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# Epoch: 0020 cost = 0.000448 output size:  <built-in method size of Tensor object at 0x7fccbc32d230>
# Epoch: 0020 cost = 0.000448 output size:  <built-in method size of Tensor object at 0x7fccbc32d650>
# Epoch: 0020 cost = 0.000447 output size:  <built-in method size of Tensor object at 0x7fccbc32d0b0>
# Epoch: 0020 cost = 0.000447 output size:  <built-in method size of Tensor object at 0x7fccbc32d890>
# Epoch: 0020 cost = 0.000446 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0020 cost = 0.000445 output size:  <built-in method size of Tensor object at 0x7fccbc32d0b0>
# Epoch: 0020 cost = 0.000445 output size:  <built-in method size of Tensor object at 0x7fccbc32d290>
# Epoch: 0020 cost = 0.000444 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0020 cost = 0.000444 output size:  <built-in method size of Tensor object at 0x7fccbc32d0b0>
# Epoch: 0020 cost = 0.000443 output size:  <built-in method size of Tensor object at 0x7fccbc32d290>
# Epoch: 0020 cost = 0.000443 output size:  <built-in method size of Tensor object at 0x7fccbc32d830>
# Epoch: 0020 cost = 0.000442 output size:  <built-in method size of Tensor object at 0x7fccbc32d5f0>
# ...
# Epoch: 0045 cost = 0.000188 output size:  <built-in method size of Tensor object at 0x7fccbc337950>
# Epoch: 0045 cost = 0.000188 output size:  <built-in method size of Tensor object at 0x7fccbc3375f0>
# Epoch: 0045 cost = 0.000188 output size:  <built-in method size of Tensor object at 0x7fccbc3378f0>
# Epoch: 0045 cost = 0.000188 output size:  <built-in method size of Tensor object at 0x7fccbc337ad0>
# Epoch: 0045 cost = 0.000188 output size:  <built-in method size of Tensor object at 0x7fccbc3375f0>
# Epoch: 0045 cost = 0.000188 output size:  <built-in method size of Tensor object at 0x7fccbc3378f0>
# Epoch: 0045 cost = 0.000187 output size:  <built-in method size of Tensor object at 0x7fccbc337ad0>
# Epoch: 0045 cost = 0.000187 output size:  <built-in method size of Tensor object at 0x7fccbc337470>
# Epoch: 0045 cost = 0.000187 output size:  <built-in method size of Tensor object at 0x7fccbc3375f0>
# Epoch: 0045 cost = 0.000187 output size:  <built-in method size of Tensor object at 0x7fccbc337650>
# Epoch: 0045 cost = 0.000187 output size:  <built-in method size of Tensor object at 0x7fccbc337470>
# Epoch: 0045 cost = 0.000186 output size:  <built-in method size of Tensor object at 0x7fccbc3375f0>
# Epoch: 0045 cost = 0.000186 output size:  <built-in method size of Tensor object at 0x7fccbc337290>
# Epoch: 0045 cost = 0.000186 output size:  <built-in method size of Tensor object at 0x7fccbc337470>
# Epoch: 0045 cost = 0.000186 output size:  <built-in method size of Tensor object at 0x7fccbc3378f0>
# Epoch: 0045 cost = 0.000186 output size:  <built-in method size of Tensor object at 0x7fccbc3376b0>
# Epoch: 0045 cost = 0.000186 output size:  <built-in method size of Tensor object at 0x7fccbc337830>
# Epoch: 0045 cost = 0.000186 output size:  <built-in method size of Tensor object at 0x7fccbc3378f0>
# Epoch: 0045 cost = 0.000186 output size:  <built-in method size of Tensor object at 0x7fccbc3376b0>
# Epoch: 0045 cost = 0.000186 output size:  <built-in method size of Tensor object at 0x7fccbc337830>
# Epoch: 0045 cost = 0.000185 output size:  <built-in method size of Tensor object at 0x7fccbc337470>
# Epoch: 0045 cost = 0.000185 output size:  <built-in method size of Tensor object at 0x7fccbc3378f0>
# Epoch: 0045 cost = 0.000185 output size:  <built-in method size of Tensor object at 0x7fccbc3379b0>
# Epoch: 0045 cost = 0.000185 output size:  <built-in method size of Tensor object at 0x7fccbc337470>
# Epoch: 0045 cost = 0.000185 output size:  <built-in method size of Tensor object at 0x7fccbc3378f0>
# Epoch: 0045 cost = 0.000185 output size:  <built-in method size of Tensor object at 0x7fccbc3379b0>
# Training Iteration 0 of epoch 45 complete. Loss: 0.02597593329846859; Time taken (s): 0.05098366737365723
# Training Iteration 0 of epoch 46 complete. Loss: 0.024798091500997543; Time taken (s): 0.038729190826416016
# Training Iteration 0 of epoch 47 complete. Loss: 0.02367904968559742; Time taken (s): 0.03984880447387695
# Training Iteration 0 of epoch 48 complete. Loss: 0.022615445777773857; Time taken (s): 0.038050174713134766
# Epoch: 0050 cost = 0.021604 output size:  <built-in method size of Tensor object at 0x7fccbc337530>
# Training Iteration 0 of epoch 49 complete. Loss: 0.021603917703032494; Time taken (s): 0.044982194900512695
# Epoch: 0050 cost = 0.020905 output size:  <built-in method size of Tensor object at 0x7fccbc3377d0>
# Epoch: 0050 cost = 0.045390 output size:  <built-in method size of Tensor object at 0x7fccbc3373b0>
# Epoch: 0050 cost = 0.063898 output size:  <built-in method size of Tensor object at 0x7fccbc337590>
# Epoch: 0050 cost = 0.895861 output size:  <built-in method size of Tensor object at 0x7fccbc3377d0>
# Epoch: 0050 cost = 0.855263 output size:  <built-in method size of Tensor object at 0x7fccbc3373b0>
# Epoch: 0050 cost = 0.871957 output size:  <built-in method size of Tensor object at 0x7fccbc337b90>
# Epoch: 0050 cost = 0.819126 output size:  <built-in method size of Tensor object at 0x7fccbc3377d0>
# Epoch: 0050 cost = 0.520044 output size:  <built-in method size of Tensor object at 0x7fccbc3373b0>
# Epoch: 0050 cost = 0.813691 output size:  <built-in method size of Tensor object at 0x7fccbc337b90>
# Epoch: 0050 cost = 0.613532 output size:  <built-in method size of Tensor object at 0x7fccbc337290>
# Epoch: 0050 cost = 0.870235 output size:  <built-in method size of Tensor object at 0x7fccbc337830>
# Epoch: 0050 cost = 0.726571 output size:  <built-in method size of Tensor object at 0x7fccbc337a70>
# Epoch: 0050 cost = 0.747482 output size:  <built-in method size of Tensor object at 0x7fccbc337290>
# Epoch: 0050 cost = 0.825264 output size:  <built-in method size of Tensor object at 0x7fccbc337830>
# Epoch: 0050 cost = 0.101511 output size:  <built-in method size of Tensor object at 0x7fccbc337a70>
# Epoch: 0050 cost = 0.000196 output size:  <built-in method size of Tensor object at 0x7fccbc337290>
# Epoch: 0050 cost = 0.000193 output size:  <built-in method size of Tensor object at 0x7fccbc337830>
# Epoch: 0050 cost = 0.000190 output size:  <built-in method size of Tensor object at 0x7fccbc337530>
# Epoch: 0050 cost = 0.000188 output size:  <built-in method size of Tensor object at 0x7fccbc3373b0>
# Epoch: 0050 cost = 0.000186 output size:  <built-in method size of Tensor object at 0x7fccbc337ad0>
# Epoch: 0050 cost = 0.000184 output size:  <built-in method size of Tensor object at 0x7fccbc337230>
# Epoch: 0050 cost = 0.000183 output size:  <built-in method size of Tensor object at 0x7fccbc337290>
# Epoch: 0050 cost = 0.000181 output size:  <built-in method size of Tensor object at 0x7fccbc337ad0>
# Epoch: 0050 cost = 0.000180 output size:  <built-in method size of Tensor object at 0x7fccbc337a70>
# Epoch: 0050 cost = 0.000179 output size:  <built-in method size of Tensor object at 0x7fccbc337290>
# Epoch: 0050 cost = 0.000178 output size:  <built-in method size of Tensor object at 0x7fccbc3375f0>
# Epoch: 0050 cost = 0.000177 output size:  <built-in method size of Tensor object at 0x7fccbc3372f0>
# Epoch: 0050 cost = 0.000176 output size:  <built-in method size of Tensor object at 0x7fccbc337530>
# Epoch: 0050 cost = 0.000175 output size:  <built-in method size of Tensor object at 0x7fccbc3379b0>
# Epoch: 0050 cost = 0.000174 output size:  <built-in method size of Tensor object at 0x7fccbc3372f0>
# Epoch: 0050 cost = 0.000174 output size:  <built-in method size of Tensor object at 0x7fccbc337530>
# Epoch: 0050 cost = 0.000173 output size:  <built-in method size of Tensor object at 0x7fccbc3379b0>
# Epoch: 0050 cost = 0.000172 output size:  <built-in method size of Tensor object at 0x7fccbc3372f0>
# Epoch: 0050 cost = 0.000172 output size:  <built-in method size of Tensor object at 0x7fccbc337530>
# Epoch: 0050 cost = 0.000172 output size:  <built-in method size of Tensor object at 0x7fccbc3379b0>
# Epoch: 0050 cost = 0.000171 output size:  <built-in method size of Tensor object at 0x7fccbc3372f0>
# Epoch: 0050 cost = 0.000171 output size:  <built-in method size of Tensor object at 0x7fccbc3375f0>
# Epoch: 0050 cost = 0.000170 output size:  <built-in method size of Tensor object at 0x7fccbc3377d0>
# Epoch: 0050 cost = 0.000170 output size:  <built-in method size of Tensor object at 0x7fccbc337530>
# Epoch: 0050 cost = 0.000170 output size:  <built-in method size of Tensor object at 0x7fccbc337bf0>
# Epoch: 0050 cost = 0.000170 output size:  <built-in method size of Tensor object at 0x7fccbc337650>
# Epoch: 0050 cost = 0.000169 output size:  <built-in method size of Tensor object at 0x7fccbc337710>
# Epoch: 0050 cost = 0.000169 output size:  <built-in method size of Tensor object at 0x7fccbc337530>
# Epoch: 0050 cost = 0.000168 output size:  <built-in method size of Tensor object at 0x7fccbc337290>
# Epoch: 0050 cost = 0.000168 output size:  <built-in method size of Tensor object at 0x7fccbc337bf0>
# Epoch: 0050 cost = 0.000168 output size:  <built-in method size of Tensor object at 0x7fccbc337530>
# Epoch: 0050 cost = 0.000168 output size:  <built-in method size of Tensor object at 0x7fccbc3372f0>
# Epoch: 0050 cost = 0.000168 output size:  <built-in method size of Tensor object at 0x7fccbc337650>
# Epoch: 0050 cost = 0.000167 output size:  <built-in method size of Tensor object at 0x7fccbc337530>
# Epoch: 0050 cost = 0.000167 output size:  <built-in method size of Tensor object at 0x7fccbc3372f0>
# Epoch: 0050 cost = 0.000167 output size:  <built-in method size of Tensor object at 0x7fccbc337710>
# Epoch: 0050 cost = 0.000167 output size:  <built-in method size of Tensor object at 0x7fccbc3377d0>
# Epoch: 0050 cost = 0.000167 output size:  <built-in method size of Tensor object at 0x7fccbc3372f0>
# Epoch: 0050 cost = 0.000166 output size:  <built-in method size of Tensor object at 0x7fccbc337290>
# Epoch: 0050 cost = 0.000166 output size:  <built-in method size of Tensor object at 0x7fccbc337890>
# Epoch: 0050 cost = 0.000166 output size:  <built-in method size of Tensor object at 0x7fccbc337350>
# Epoch: 0050 cost = 0.000166 output size:  <built-in method size of Tensor object at 0x7fccbc3373b0>
# Epoch: 0050 cost = 0.000166 output size:  <built-in method size of Tensor object at 0x7fccbc337bf0>
# Epoch: 0050 cost = 0.000166 output size:  <built-in method size of Tensor object at 0x7fccbc337650>
# Epoch: 0050 cost = 0.000165 output size:  <built-in method size of Tensor object at 0x7fccbc337530>
# Epoch: 0050 cost = 0.000165 output size:  <built-in method size of Tensor object at 0x7fccbc337950>
# Epoch: 0050 cost = 0.000165 output size:  <built-in method size of Tensor object at 0x7fccbc337650>
# Epoch: 0050 cost = 0.000165 output size:  <built-in method size of Tensor object at 0x7fccbc3377d0>
# Epoch: 0050 cost = 0.000165 output size:  <built-in method size of Tensor object at 0x7fccbc337bf0>
# Epoch: 0050 cost = 0.000165 output size:  <built-in method size of Tensor object at 0x7fccbc337770>
# Epoch: 0050 cost = 0.000165 output size:  <built-in method size of Tensor object at 0x7fccbc3377d0>
# Epoch: 0050 cost = 0.000165 output size:  <built-in method size of Tensor object at 0x7fccbc337ad0>
# Epoch: 0050 cost = 0.000165 output size:  <built-in method size of Tensor object at 0x7fccbc3375f0>
# Epoch: 0050 cost = 0.000164 output size:  <built-in method size of Tensor object at 0x7fccbc3372f0>
# Epoch: 0050 cost = 0.000164 output size:  <built-in method size of Tensor object at 0x7fccbc337ad0>
# Epoch: 0050 cost = 0.000164 output size:  <built-in method size of Tensor object at 0x7fccbc3375f0>
# Epoch: 0050 cost = 0.000164 output size:  <built-in method size of Tensor object at 0x7fccbc337a70>
# Epoch: 0050 cost = 0.000164 output size:  <built-in method size of Tensor object at 0x7fccbc337710>
# Epoch: 0050 cost = 0.000164 output size:  <built-in method size of Tensor object at 0x7fccbc337350>
# Epoch: 0050 cost = 0.000164 output size:  <built-in method size of Tensor object at 0x7fccbc337950>
# Epoch: 0050 cost = 0.000164 output size:  <built-in method size of Tensor object at 0x7fccbc337530>
# Epoch: 0050 cost = 0.000163 output size:  <built-in method size of Tensor object at 0x7fccbc337710>
# Epoch: 0050 cost = 0.000163 output size:  <built-in method size of Tensor object at 0x7fccbc3373b0>
# Epoch: 0050 cost = 0.000163 output size:  <built-in method size of Tensor object at 0x7fccbc337530>
# Epoch: 0050 cost = 0.000163 output size:  <built-in method size of Tensor object at 0x7fccbc337590>
# Epoch: 0050 cost = 0.000163 output size:  <built-in method size of Tensor object at 0x7fccbc337b90>
# Epoch: 0050 cost = 0.000163 output size:  <built-in method size of Tensor object at 0x7fccbc337ad0>
# Epoch: 0050 cost = 0.000163 output size:  <built-in method size of Tensor object at 0x7fccbc337770>
# Epoch: 0050 cost = 0.000163 output size:  <built-in method size of Tensor object at 0x7fccbc337b90>
# Epoch: 0050 cost = 0.000163 output size:  <built-in method size of Tensor object at 0x7fccbc337230>
# Epoch: 0050 cost = 0.000163 output size:  <built-in method size of Tensor object at 0x7fccbc337ad0>
# Epoch: 0050 cost = 0.000163 output size:  <built-in method size of Tensor object at 0x7fccbc3373b0>
# Epoch: 0050 cost = 0.000162 output size:  <built-in method size of Tensor object at 0x7fccbc337230>
# Epoch: 0050 cost = 0.000162 output size:  <built-in method size of Tensor object at 0x7fccbc337a70>
# Epoch: 0050 cost = 0.000162 output size:  <built-in method size of Tensor object at 0x7fccbc337590>
# Epoch: 0050 cost = 0.000162 output size:  <built-in method size of Tensor object at 0x7fccbc337ad0>
# Epoch: 0050 cost = 0.000162 output size:  <built-in method size of Tensor object at 0x7fccbc337a70>
# Epoch: 0050 cost = 0.000162 output size:  <built-in method size of Tensor object at 0x7fccbc337590>
# Epoch: 0050 cost = 0.000161 output size:  <built-in method size of Tensor object at 0x7fccbc337ad0>
# Epoch: 0050 cost = 0.000161 output size:  <built-in method size of Tensor object at 0x7fccbc337350>
# Epoch: 0050 cost = 0.000161 output size:  <built-in method size of Tensor object at 0x7fccbc337590>
# Epoch: 0050 cost = 0.000161 output size:  <built-in method size of Tensor object at 0x7fccbc337ad0>
# Epoch: 0050 cost = 0.000161 output size:  <built-in method size of Tensor object at 0x7fccbc3373b0>
# Epoch: 0050 cost = 0.000161 output size:  <built-in method size of Tensor object at 0x7fccbc337650>
# Epoch: 0050 cost = 0.000161 output size:  <built-in method size of Tensor object at 0x7fccbc337b90>
# Epoch: 0050 cost = 0.000161 output size:  <built-in method size of Tensor object at 0x7fccbc337890>
# Epoch: 0050 cost = 0.000161 output size:  <built-in method size of Tensor object at 0x7fccbc337650>
# Epoch: 0050 cost = 0.000160 output size:  <built-in method size of Tensor object at 0x7fccbc337950>
# Epoch: 0050 cost = 0.000160 output size:  <built-in method size of Tensor object at 0x7fccbc337770>
# Epoch: 0050 cost = 0.000160 output size:  <built-in method size of Tensor object at 0x7fccbc337b90>
# Epoch: 0050 cost = 0.000160 output size:  <built-in method size of Tensor object at 0x7fccbc337a70>
# Epoch: 0050 cost = 0.000160 output size:  <built-in method size of Tensor object at 0x7fccbc337590>
# Epoch: 0050 cost = 0.000160 output size:  <built-in method size of Tensor object at 0x7fccbc3377d0>
# Epoch: 0050 cost = 0.000160 output size:  <built-in method size of Tensor object at 0x7fccbc337830>
# Epoch: 0050 cost = 0.000160 output size:  <built-in method size of Tensor object at 0x7fccbc337590>
# Epoch: 0050 cost = 0.000160 output size:  <built-in method size of Tensor object at 0x7fccbc337770>
# Epoch: 0050 cost = 0.000160 output size:  <built-in method size of Tensor object at 0x7fccbc337830>
# Epoch: 0050 cost = 0.000159 output size:  <built-in method size of Tensor object at 0x7fccbc337ad0>
# Epoch: 0050 cost = 0.000159 output size:  <built-in method size of Tensor object at 0x7fccbc337770>
# Epoch: 0050 cost = 0.000159 output size:  <built-in method size of Tensor object at 0x7fccbc337b90>
# Epoch: 0050 cost = 0.000159 output size:  <built-in method size of Tensor object at 0x7fccbc337830>
# Epoch: 0050 cost = 0.000159 output size:  <built-in method size of Tensor object at 0x7fccbc337230>
# Epoch: 0050 cost = 0.000159 output size:  <built-in method size of Tensor object at 0x7fccbc337b90>
# Epoch: 0050 cost = 0.000159 output size:  <built-in method size of Tensor object at 0x7fccbc337830>
# Epoch: 0050 cost = 0.000159 output size:  <built-in method size of Tensor object at 0x7fccbc337770>
# Epoch: 0050 cost = 0.000159 output size:  <built-in method size of Tensor object at 0x7fccbc337890>
# Epoch: 0050 cost = 0.000159 output size:  <built-in method size of Tensor object at 0x7fccbc3375f0>
# Epoch: 0050 cost = 0.000158 output size:  <built-in method size of Tensor object at 0x7fccbc337590>
# Epoch: 0050 cost = 0.000158 output size:  <built-in method size of Tensor object at 0x7fccbc337950>
# Epoch: 0050 cost = 0.000158 output size:  <built-in method size of Tensor object at 0x7fccbc3375f0>
# Epoch: 0050 cost = 0.000158 output size:  <built-in method size of Tensor object at 0x7fccbc337590>
# Epoch: 0050 cost = 0.000158 output size:  <built-in method size of Tensor object at 0x7fccbc337950>

# %%
best_model = NNLM()
best_model.load_state_dict(torch.load(best_model_path))
best_model.cuda(gpu)

cos = nn.CosineSimilarity(dim=0)

lm_similarities = {}
# word pairs to calculate similarity
words = {('women','wife'),('king','man'),('london','paris'),('male','husband')}

# ----------- Calculate LM similarities using cosine similarity ----------
for word_pairs in words:
    w1 = word_pairs[0]
    w2 = word_pairs[1]
    words_tensor = torch.LongTensor([word_to_index.get(w1,word_to_index['<UNK>']),word_to_index.get(w2,word_to_index['<UNK>'])])
    
    words_tensor = words_tensor.cuda(gpu)
    # get word embeddings from the best model
    words_embeds = best_model.embeddings(words_tensor)
    # calculate cosine similarity between word vectors
    sim = cos(words_embeds[0],words_embeds[1])
    lm_similarities[word_pairs] = sim.item()

print(lm_similarities)
# Out:
# {('women', 'wife'): -0.06410741806030273, ('male', 'husband'): 0.182801753282547, ('london', 'paris'): 0.20396174490451813, ('king', 'man'): -0.3138909935951233}

# %%
best_model.embeddings(torch.LongTensor([word_to_index.get('london')]).cuda(gpu)) # Test the embeddings here
# Out:
# tensor([[-1.6988, -0.9228,  0.2194,  1.5367,  0.6088,  0.2180,  0.5907,  0.2546,
#          -1.5363,  1.8164]], device='cuda:0', grad_fn=<EmbeddingBackward0>)
