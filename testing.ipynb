# %% [markdown]
# <a href="https://colab.research.google.com/github/kefasmanu/NLP-FELLOWSHIP/blob/main/testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# %%
people_string = '''
{
  "people":[
{

  "name": "John Smith",
  "Phone": "615-555-7164",
  "emails": ["johnsmith@bogusemail.com", "john.smith@work-place.com"],
  "has_liscene":false
},
{
  "name": "John Doe",
  "Phone": "56-555-5156",
  "emails": null,
  "has_liscene":true
}
]
}
'''

data = json.loads(people_string)

# %%
print(data)
# Out:
# {'people': [{'name': 'John Smith', 'Phone': '615-555-7164', 'emails': ['johnsmith@bogusemail.com', 'john.smith@work-place.com'], 'has_liscene': False}, {'name': 'John Doe', 'Phone': '56-555-5156', 'emails': None, 'has_liscene': True}]}

# %%
for person in data['people']:
  del person['Phone']


new_string = json.dumps(data, indent=2, sort_keys=True)

# %%
print(new_string)
# Out:
# {
#   "people": [
#     {
#       "emails": [
#         "johnsmith@bogusemail.com",
#         "john.smith@work-place.com"
#       ],
#       "has_liscene": false,
#       "name": "John Smith"
#     },
#     {
#       "emails": null,
#       "has_liscene": true,
#       "name": "John Doe"
#     }
#   ]
# }

# %%
with open('states.json')as f:
  data = json.load(f)

# %%
#lodaing a website into json

from  urllib.request import urlopen

with urlopen("https://finance.yahoo.com/?guccounter=1&guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&guce_referrer_sig=AQAAAKGh1btCLAwOYOEQDNpkoiGl2rnSlNCS7pzWOetm1dGuGo7QIO2_Hx24s_-3WFedHJEuhodQvThdDf6sDzYU7DdlGoHS24rRW7WCoeD4y97fzdgpzUi7B1wHoRArKil4uHvxsPutuAAOftbuai0FIArQs44oie7qq1F2EN6D6vQV?format=json") as response:
  source = response.read()


print(source)
# Out:
# b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x00\xec\xbd\xebz\xdbF\x920\xfc\x7f\xae\x02f\x12\x9b\\\x13\x10\x0e<\xd3\xb4G\'\xc7\x9a\x91,\x8d$\xc7\x93\xf1z\xf9\x80@\x83D\x0c\x02\x0c\x00J\xa2\x15\xbe\xcf^\xc6\xf7\xde\xde^\xc9WU\xdd8\x92\x94)\xf9\x90\xc9\xbe\x89\x1d\x13htWWWUWU\x9f\xaa\x9f=:8\xdd\xbf\xfc\xf9\xecP\x9a\xc4S\xef\xf93\xfcW\xb2\xcd\xd8\x94\xad\xc0\x0bB9\x9e\xb0)\x1bT<w<\x89+\x92k\x0f*f\x1cL]\xab"Y\x9e\x19E\x83\xca\xeb\xe0o\x91dM\xc2`\xca$\x9bE\x1f\xe2`&9\xa6\xebE\xa6\xc3*\x92g\xfa\xe3A\x85\xf9\xf2\x9b\x8b\n\x00g\xa6-\xcdB\xe6\xb87\x83J0\xeeA\x9d\xf1\xac\xb7\xb3\x13\x8cg\xca\x94\xed\xf8\xd1w\x90)\xb2Bw\x16?\xbfv};\xb8Vf,t\x82pj\xfa\x16\x93\x1e?\x96VS\x95\xa9\x19~\xb8\xe3S\xf5\xc9\x999f\x17\xb1\x19\xc6Oj\xfdg;\x02\xfc\xb3)\x8bM\xc0\xdb\x0c#\x16\x0f*\xf3\xd8\x91;\x15i\xe7\xf9\xb3\xd8\x8d=\xf6\xfcgs\x12\x04\xd2K\xd7\xa7\x8ae\xe9"\x0e\xac\x0f\xd2\t\xc0c\xb1t\xec^\xb1\xba\xf4\x8fy\x10\xb3\xa8.\xed\xcd#\xd7gQ$=6\xa7\xb3~Z\xe65\xbb\x8e\x9e\xedph\xbc2\xdfDJ~`\x8b\xeb \xb4# `\xe0\xc7\xcc\x87
# ...
